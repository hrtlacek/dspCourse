# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
length = 500
x = np.linspace(0, 3*np.pi, length)
chirp = np.sin(x**2)
plt.plot(x, chirp)
plt.title('A simple chirp');

# %%
randSig = []
for i in range(length):
    randSig.append(random.random()*0.5)
plt.plot(x, randSig)
plt.title('Noise');

# %%
mySignal = randSig+chirp
plt.plot(x, mySignal)
plt.title('A test Signal');

# %%
def findPeaks(source, spread, iterations):
    mIndex = []
    newSource = source
    for j in range (iterations):

        mIndex.append(np.argmax(newSource))



    	for i in range ((spread*2)+1):
    	    delStartPoint = np.clip(mIndex[j]-(spread), 0, len(source)-1)
    	    #print delStartPoint
    	    delIndex = np.clip(delStartPoint+i, 0, len(source)-1) 
    	    newSource[delIndex] = 0
    		
    return mIndex, newSource

# %%
def findPeaks2(source, spread, iterations):
    mIndex = []
    newSource = source
    for j in range (iterations):

        mIndex.append(np.argmax(newSource))



    	for i in range ((spread*2)+1):
    	    delStartPoint = np.clip(mIndex[j]-(spread), 0, len(source)-1)
    	    #print delStartPoint
    	    delIndex = np.clip(delStartPoint+i, 0, len(source)-1) 
    	    newSource[delIndex] = 0
    		
    return mIndex, newSource

# %%
def getDerivative(source):
	result = []
	for i in range (len(source)):
		der = source[i]-source[max(0, i-1)]
		result.append(der)
	return result

# %%
test = range(5)
for i in range(3):
    test.append(i)

# %%
test
# Out:
# [0, 1, 2, 3, 4, 0, 1, 2]

# %%
findPeaks(test, 1, 1)
# Out:
# 3
# 3
# 3
# ([4], [0, 1, 2, 0, 0, 0, 1, 2])

# %%
findPeaks(test, 2, 1)
# Out:
# 0
# 0
# 0
# 0
# 0
# ([2], [0, 0, 0, 0, 0, 0, 1, 2])

# %%
testSignal = []
for i in range(len(mySignal)):
    testSignal.append(mySignal[i])
plt.plot(x, testSignal)
plt.title('Marker');

# %%
peaks = []

# %%
result = findPeaks(testSignal, 7, 14)
peaks = result[0]

print peaks
# Out:
# [64, 358, 273, 148, 238, 199, 446, 305, 75, 466, 426, 381, 330, 54]

# %%
marker = np.zeros(length)
for k in peaks: 
    marker[peaks]=1

# %%
plt.plot(x, marker)


plt.plot(x, chirp)
plt.title('Marker');

# %%
def findPeaks2(source, spread, iterations):
    import numpy as np
    import copy
    
    mIndex = []
    newSource = copy.deepcopy(source)
    for j in range (iterations):
        mIndex.append(np.argmax(newSource))
        for i in range ((spread*2)+1):
            delStartPoint = np.clip(mIndex[j]-(spread), 0, len(source)-1)
            #print delStartPoint
            delIndex = np.clip(delStartPoint+i, 0, len(source)-1) 
            newSource[delIndex] = 0

    return mIndex, newSource

# %%
def markerCreate(testSignal, spread, iterations):
    
    peaks = []
    result = findPeaks2(testSignal, spread, iterations)
    peaks = result[0]

    #print peaks
    marker = np.zeros(len(testSignal))
    marker = marker-1

    for k in peaks: 
        marker[k]=testSignal[k]
    return marker, peaks
#There is some problem here.. it overwrites things it shouldn't

# %%
#Below the real Data is assigned the string variable strlist

# %%
0.0007 0.000715 0.001263 0.001863 0.002294 0.002417 0.002458 0.002226 0.001844 0.001685 0.001361 0.001124 0.000979 0.000755 0.000663 0.000631 0.000703 0.000739 0.000793 0.000596 0.000442 0.000373 0.000359 0.000454 0.000424 0.000359 0.000347 0.000359 0.000361 0.000284 0.000155 0.000078 0.000194 0.000328 0.000312 0.000475 0.00059 0.000515 0.000509 0.000587 0.00048 0.000509 0.000523 0.000686 0.000794 0.000883 0.000736 0.000576 0.000498 0.000521 0.000456 0.000278 0.000137 0.000098 0.000186 0.000433 0.000587 0.000796 0.000899 0.000911 0.000764 0.000599 0.000359 0.000474 0.000622"

# %%
frame = strlist.split(' ')
for i in range(len(frame)):
    frame[i] = float(frame[i])
print type (frame[0])
# Out:
# <type 'float'>

# %%
plt.figure(figsize=(30,20))
#make list of floats out of string----
frame = strlist.split(' ')
for i in range(len(frame)):
    frame[i] = float(frame[i])
#-------------------------------------
x2 = range(len(frame))
plt.plot(x2, frame)
marks = markerCreate(frame, 7, 14)[0]

plt.plot(x2, marks, 'rx', markersize=15)
plt.title('RealData');
plt.axis([0, 4096, 0, 1.2])
# Out:
# [0, 4096, 0, 1.2]

# %%
#-- A running Average Filter--
def runningAverage(x, a):
    z1 = 0
    y = []
    for n in range(len(x)):
        if n > 0:
            z1 = x[n-1] 
        y.append((x[n]*a)+(z1*(1.-a))) 
    return y

# %%
#-- A non-kausal Filter--
def nonKausalFIR1(x, order):
    z = np.zeros((order*2)+1)
    #print z
    y = []
    for n in range(len(x)):
        
        #fill buffer, so z, with past and future samples
        for i in range((order*2)+1):
            index = np.clip(n-order+i, 0, len(x)-1)
            

            #print "index = "+str(index)
            #print "i = "+str(i)
            #print "z[i] = "+str(z[i])
            #print "z[index] = "+str(x[index])
            z[i]= x[index]
            z[order]=0
        
        #weigth
        temp = (x[n]+sum(z))*(1./((order*2)+1))
        y.append(temp)
    return y

# %%
#-- A One-Pole --
def onePole(x, a):
    z1 = 0
    y = []
    for n in range(len(x)):
        if n > 0:
            z1 = y[n-1] 
        y.append((x[n]*a)+(z1*(1.-a))) 
    return y

# %%
nklp = nonKausalFIR1(frame, 30)

n = range(len(nklp))
plt.plot(n, nklp)

# %%
lp = onePole(frame, 0.015)

n = range(len(lp))
plt.plot(n, lp)

# %%
#--create Convolution Kernel
def kernelCreate(length, decay):
    import math
    
    kernel = []
    
    n = range(length)
    for i in range(length):
        sample = math.exp(-i*decay)
        kernel.append(float(sample))
    return kernel

# %%
#--create Convolution Kernel
decay = 0.05
length = 100
kernel = kernelCreate(length, decay)
n = range(length)
plt.stem(n, kernel)
plt.axis([-1, length,0,1.2])
# Out:
# [-1, 100, 0, 1.2]

# %%
plt.figure(figsize=(30,20))
plt.axis([0, 500, 0, 1.2])

#make list of floats out of string----
frame = strlist.split(' ')
for i in range(len(frame)):
    frame[i] = float(frame[i])
#-------------------------------------

#-------IndexSIgnal
x2 = range(len(frame))


#--plot OriginalFrame
plt.plot(x2, frame, 'b--')



# ------ a non-Kausal FIR Lowpass

lp2 = nonKausalFIR1(frame, 5)
# ------post-amplify
lp2[:] = [x*1 for x in lp2]
plt.plot(x2, lp2, 'g-')



# ------ a simple FIR Lowpass

#lp = onePole(frame, 0.015)
# ------post-amplify
#lp[:] = [x*10 for x in lp] 
#plt.plot(x2, lp, '--')


# -----Convolution
conv = np.convolve(lp2,kernel)
conv = conv[:4096]
# ------post-amplify
conv[:] = [x*0.25 for x in conv]
plt.plot(x2, conv, 'g--')



res = markerCreate(conv, 50, 14)
marks = res[0]
bins = res[1]
print "Bins:"+str(bins)
plt.plot(x2, marks, 'rx', markersize=15)

plt.title('RealData');
# Out:
# Bins:[319, 370, 592, 1096, 708, 643, 880, 52, 421, 1603, 541, 1493, 1147, 938]

# %% [markdown]
# Below a first order polynomial is fit to the frame. This is then subtracted from the frame, so DC offset in the FFT data(not the time domain data) is removed.

# %%
def leastSquaresLine(data):
    polycoeffs = np.polyfit(range(len(data)), data, 1)
    line = []
    for i in range(len(data)):
        y =np.polyval(polycoeffs, i)
        line.append(y)
    return line

def pDcBlock(data):
    return data-leastSquaresLine(data)

# %%
print (len(frame))
a = np.polyfit(range(len(frame)),frame, 1)
plt.plot(x2, frame)
plt.plot(x2, leastSquaresLine(frame), "r")
# Out:
# 4096

# %%
print a
# Out:
# [ -4.88014585e-06   1.60186848e-02]

# %%
def derivative(data):
    der = []
    for i in range(len(data)):
        if i != 0:
            d = data[i] - data[i - 1] 
        else: 
            d = 0
        der.append(d)
    return der

# %%
delta = derivative(conv)

# %%
plt.figure(figsize =(20, 10))
plt.plot(x2, delta)
plt.title('Derivative of Convolved frame')

# %%
secondDelta = derivative(conv)

# %%
plt.figure(figsize =(20, 10))
plt.plot(x2, secondDelta)
plt.title('second Derivative of Convolved frame')

# %%
def findZeros(data, threshold):
    zeros = np.zeros(len(data))
    zeros = zeros-1
    for i in range(len(data)):
        if data[i]<threshold:
            zeros[i]=1
    return zeros

# %%
plt.plot(x2, frame)

plt.plot(x2, findZeros(delta, 0.00001), "rx")
plt.axis([0, 4096, 0, 1])
# Out:
# [0, 4096, 0, 1]

# %%
def gating(zeros, data, thresh):
    import copy
    peaks = []
    marks = copy.copy(zeros)
    for i in range(len(data)):
        if zeros[i] == 1:
            if data[i]>= thresh:
                peaks.append(i)
                marks[i]=data[i]
            else:
                marks[i]=-1
                
    return peaks,marks

# %%
plt.figure(figsize=(20,10))
plt.plot(x2, frame)
result = gating(findZeros(derivative(frame), 0.00001), frame, 0.07)
print result[0]
crosses = result[1]
plt.plot(x2, crosses, "ro")

#plt.plot(x2, findZeros(delta, 0.00001), "rx")
plt.axis([0, 4096, 0, 1])
# Out:
# [309, 315, 317, 342, 345, 1092]
# [0, 4096, 0, 1]

# %%
plt.figure(figsize=(20,10))
plt.plot(x2, frame)

marks = markerCreate(secondDelta, 7, 14)[0]
#print len(marks)
plt.plot(x2, marks, 'ro', markersize=15)

#plt.plot(x2, findZeros(delta, 0.00001), "rx")
plt.axis([0, 4096, 0, 1])
# Out:
# [0, 4096, 0, 1]

# %%
def peakfinder3(data):
